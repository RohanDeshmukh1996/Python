# %%
import numpy as np

# %%
# Task 1
# using genfromtxt function to convert data  to array
adm_data=np.genfromtxt('DS1_C4_S1_AdmissionPredict_Data_Practice.csv', delimiter=',', skip_header=1)

# %%
print(adm_data.shape) # displaying rows and column
# Out:
# (400, 9)

# %%
#Task 2
# displaying gre score of all student using slice
a=adm_data[x][0:,0]
b=adm_data[x][0:,1]
print("%7s %20s"%("Serial no","GRE Score"))
for i in range(len(a)):
    print("%5s %20s"%(a[i],b[i]))
# Out:
# Serial no            GRE Score
#   1.0                337.0
#   6.0                330.0
#  12.0                327.0
#  13.0                328.0
#  22.0                325.0
#  23.0                328.0
#  24.0                334.0
#  25.0                336.0
#  26.0                340.0
#  33.0                338.0
#  34.0                340.0
#  35.0                331.0
#  44.0                332.0
#  45.0                326.0
#  47.0                329.0
#  48.0                339.0
#  50.0                327.0
#  53.0                334.0
#  54.0                324.0
#  65.0                325.0
#  66.0                325.0
#  67.0                327.0
#  70.0                328.0
#  71.0                332.0
#  72.0                336.0
#  73.0                321.0
#  76.0                329.0
#  77.0                327.0
#  82.0                340.0
#  84.0                322.0
#  85.0                340.0
#  98.0                331.0
#  99.0                332.0
# ...

# %%
# Task 3
# using where function to give condition to array for getting index
x=np.where(adm_data[0:,1]>320)
# converting index to proper value of specific column
a=adm_data[x][0:,0]
using size for getting how many elements are present in array
print("Total nummber of student who have score more than 320 :",a.size)
# Out:
# Total nummber of student who have score more than 320 : 163

# %%
# Task 4
# using where function to give condition to specific column of array for getting index
x=np.where(adm_data[0:,2]>110)
# converting index to proper value of specific columns
a=adm_data[x][0:,0]
b=adm_data[x][0:,8]
# converting array to list for display purpose
sr=a.tolist()
per=b.tolist()
print("%7s %20s"%("Serial no","Percentage"))
for i in range(len(sr)):
    print("%5s %20s"%(sr[i],per[i]))
# Out:
# Serial no           Percentage
#   1.0                 0.92
#   6.0                  0.9
#  12.0                 0.84
#  13.0                 0.78
#  22.0                  0.7
#  23.0                 0.94
#  24.0                 0.95
#  25.0                 0.97
#  26.0                 0.94
#  33.0                 0.91
#  34.0                  0.9
#  35.0                 0.94
#  44.0                 0.87
#  45.0                 0.91
#  47.0                 0.86
#  48.0                 0.89
#  50.0                 0.78
#  53.0                 0.78
#  54.0                 0.72
#  65.0                 0.52
#  66.0                 0.55
#  67.0                 0.61
#  70.0                 0.78
#  71.0                 0.94
#  72.0                 0.96
#  73.0                 0.93
#  76.0                 0.72
#  77.0                 0.74
#  82.0                 0.96
#  84.0                 0.92
#  85.0                 0.94
#  98.0                 0.86
#  99.0                  0.9
# ...

# %%
# Task 5
# using where function to give condition to specific column of array for getting index
x=np.where((adm_data[0:,1]>315)&(adm_data[0:,2]>115)&(adm_data[0:,1]>0))
# converting index to proper value of specific columns and storing in object
l=adm_data[x][0:,0]
# length fuction to get size of array
print("Total number of Students eligible for scolarship are ", len(l))
print("Serial No.")
# converting array to list for display purpose
m=l.tolist()
for i in m:
    print("%5s"%(int(i)))
# Out:
# Total number of Students eligible for scolarship are  44
# Serial No.
#     1
#    23
#    24
#    25
#    26
#    33
#    44
#    48
#    53
#    71
#    82
#    98
#    99
#   108
#   109
#   121
#   122
#   130
#   139
#   142
#   144
#   149
#   152
#   172
#   177
#   188
#   194
#   203
#   204
#   213
#   214
#   215
#   216
#   260
#   286
#   287
#   298
#   326
#   338
#   362
#   373
#   386
#   398
#   400
