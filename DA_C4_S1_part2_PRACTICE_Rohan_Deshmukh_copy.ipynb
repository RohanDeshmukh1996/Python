# %%
import numpy as np

# %%
# Task 1
adm_data=np.genfromtxt('DS1_C4_S1_AdmissionPredict_Data_Practice.csv', delimiter=',', skip_header=1)

# %%
print(adm_data.shape) # displaying rows and column
# Out:
# (400, 9)

# %%
#Task 2
# displaying gre score of all student using slice
print("Srno.  GRE_score")
print(adm_data[0:,0:2])
# Out:
# Srno.  GRE_score
# [[  1. 337.]
#  [  2. 324.]
#  [  3. 316.]
#  [  4. 322.]
#  [  5. 314.]
#  [  6. 330.]
#  [  7. 321.]
#  [  8. 308.]
#  [  9. 302.]
#  [ 10. 323.]
#  [ 11. 325.]
#  [ 12. 327.]
#  [ 13. 328.]
#  [ 14. 307.]
#  [ 15. 311.]
#  [ 16. 314.]
#  [ 17. 317.]
#  [ 18. 319.]
#  [ 19. 318.]
#  [ 20. 303.]
#  [ 21. 312.]
#  [ 22. 325.]
#  [ 23. 328.]
#  [ 24. 334.]
#  [ 25. 336.]
#  [ 26. 340.]
#  [ 27. 322.]
#  [ 28. 298.]
#  [ 29. 295.]
#  [ 30. 310.]
#  [ 31. 300.]
#  [ 32. 327.]
#  [ 33. 338.]
#  [ 34. 340.]
#  [ 35. 331.]
#  [ 36. 320.]
#  [ 37. 299.]
#  [ 38. 300.]
#  [ 39. 304.]
#  [ 40. 307.]
#  [ 41. 308.]
#  [ 42. 316.]
#  [ 43. 313.]
#  [ 44. 332.]
#  [ 45. 326.]
#  [ 46. 322.]
#  [ 47. 329.]
#  [ 48. 339.]
#  [ 49. 321.]
#  [ 50. 327.]
#  [ 51. 313.]
#  [ 52. 312.]
#  [ 53. 334.]
#  [ 54. 324.]
#  [ 55. 322.]
#  [ 56. 320.]
#  [ 57. 316.]
#  [ 58. 298.]
#  [ 59. 300.]
#  [ 60. 311.]
#  [ 61. 309.]
#  [ 62. 307.]
#  [ 63. 304.]
#  [ 64. 315.]
#  [ 65. 325.]
# ...

# %%
# Task 3
sum=0 # for calculating count
for i in range(len(adm_data)): # loop for moving forward in array
    if adm_data[i,1]>320: # condition for gre 
        sum=sum+1
print("Total nummber of student who have score more than 320 :",sum)
# Out:
# Total nummber of student who have score more than 320 : 163

# %%
# Task 4
print("srno.  %")
for i in range(len(adm_data)):  # loop for moving forward in array
    if adm_data[i,2]>110: # condition for TOEFL score
        print(adm_data[i,0],"  ",((adm_data[i,8])*100))
# Out:
# srno.  %
# 1.0    92.0
# 6.0    90.0
# 12.0    84.0
# 13.0    78.0
# 22.0    70.0
# 23.0    94.0
# 24.0    95.0
# 25.0    97.0
# 26.0    94.0
# 33.0    91.0
# 34.0    90.0
# 35.0    94.0
# 44.0    87.0
# 45.0    91.0
# 47.0    86.0
# 48.0    89.0
# 50.0    78.0
# 53.0    78.0
# 54.0    72.0
# 65.0    52.0
# 66.0    55.00000000000001
# 67.0    61.0
# 70.0    78.0
# 71.0    94.0
# 72.0    96.0
# 73.0    93.0
# 76.0    72.0
# 77.0    74.0
# 82.0    96.0
# 84.0    92.0
# 85.0    94.0
# 98.0    86.0
# 99.0    90.0
# 100.0    79.0
# 105.0    74.0
# 107.0    87.0
# 108.0    91.0
# 109.0    93.0
# 121.0    94.0
# 122.0    94.0
# 127.0    85.0
# 128.0    78.0
# 129.0    84.0
# 130.0    92.0
# 131.0    96.0
# 134.0    79.0
# 135.0    89.0
# 139.0    80.0
# 142.0    90.0
# 143.0    92.0
# 144.0    97.0
# 145.0    80.0
# 146.0    81.0
# 148.0    83.0
# 149.0    96.0
# 151.0    93.0
# 152.0    94.0
# 153.0    86.0
# 165.0    81.0
# 172.0    89.0
# 174.0    89.0
# 175.0    87.0
# 176.0    85.0
# ...

# %%
# Task 5
sum=0 # for calculating count
print("Serial No.")
for i in range(len(adm_data)): # loop for moving forward in array
    if adm_data[i,1]>315: # condition for gre 
        if adm_data[i,2]>115: # condition for TOEFL score
            if adm_data[i,7]>0: # condition for Research
                print(adm_data[i,0])
                sum=sum+1
print("--------------------------")
print("Total number of Students eligible for scolarship are ",sum)
# Out:
# Serial No.
# 1.0
# 23.0
# 24.0
# 25.0
# 26.0
# 33.0
# 53.0
# 71.0
# 82.0
# 98.0
# 99.0
# 108.0
# 109.0
# 121.0
# 122.0
# 130.0
# 139.0
# 142.0
# 144.0
# 149.0
# 152.0
# 172.0
# 177.0
# 188.0
# 194.0
# 203.0
# 204.0
# 213.0
# 214.0
# 215.0
# 216.0
# 260.0
# 286.0
# 287.0
# 326.0
# 338.0
# 362.0
# 373.0
# 386.0
# 398.0
# 400.0
# --------------------------
# Total number of Students eligible for scolarship are  41
